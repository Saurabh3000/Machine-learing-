# %%
number=[1,2,3,4]

# %%
number
# Out:
# [1, 2, 3, 4]

# %%
print(type(number))
# Out:
# <class 'list'>

# %%
student=[4,"Aniket",99.95]

# %%
student
# Out:
# [4, 'Aniket', 99.95]

# %%
print(student[1])
# Out:
# Aniket

# %%
student.append(number)

# %%
student
# Out:
# [4, 'Aniket', 99.95, [1, 2, 3, 4]]

# %%
student.insert(2,"open")

# %%
student
# Out:
# [4, 'Aniket', 'open', 99.95, [1, 2, 3, 4]]

# %% [markdown]
# Home Work 10/08

# %%
list1=[1,"Saurabh",99.5,2,"Aniket",88.2,2,"Pratik",11,99.8,"shivraj",15,22.05,"Loku",14]
i=input("Enter a record")
if i in list1:
    print("Yes")
else:
    print("No")
# Out:
# Enter a record2
# No

# %%
a=10
b=20
c=30
a=b
b=c
c=a

# %%
a
# Out:
# 20

# %%
b
# Out:
# 30

# %%
c
# Out:
# 20

# %%
list2=["Saurabh",2,99.5,"Aniket",45,55.2]
word=input("Enter location")
for i in list2:
    if i==word:
        print(i)
    else:
        print("No")
# Out:
# Enter location3
# No
# No
# No
# No
# No
# No

# %%
list1=[1,"Saurabh",99.5,2,"Aniket",88.2,2,"Pratik",11,99.8,"shivraj",15,22.05,"Loku",14]
search=input("Enter a record")
flag=0
for i  in list2:
    if i==search:
        print(i)
        flag=0
        break
    else:
         flag=1



if flag==1:
    print("Not Found")
# Out:
# Enter a recordSaurabh
# Saurabh
