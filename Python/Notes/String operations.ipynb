# %%
str="abcdefgh"

# %% [markdown]
# String Slicing

# %%
print(str)
# Out:
# abcdefgh

# %%
print(str[-1])
# Out:
# h

# %%
print(len(str))
# Out:
# 8

# %%
print(str[2])
# Out:
# c

# %%
print(str[0])
print(str[-1])
print(str[2])
print(str[-5])
print(str[0:4])
print(str[2:6])
# Out:
# a
# h
# c
# d
# abcd
# cdef

# %% [raw]
# String Operation

# %%
str2="welcome to Python"

# %%
print('l' and 'P' in str2)
print('w' or 's' in str2)
print('a' and 'b' in str2)
# Out:
# True
# w
# False

# %%
print(str2.lower())
# Out:
# welcome to python

# %%
print(str2.upper())
# Out:
# WELCOME TO PYTHON

# %%
print(str2.isalnum())
# Out:
# False

# %%
print(str.isalpha())
# Out:
# True

# %%
str3='25795a'

# %%
print(str3.isalnum())
# Out:
# True

# %%
print(str3.isnumeric())
# Out:
# False

# %%
print(str3.isdigit())
# Out:
# False

# %%
str1='hill wlc to python'

# %%
str1.title()
# Out:
# 'Hill Wlc To Python'

# %%
print(str1.istitle())
# Out:
# False

# %%
str1.join('str2')
# Out:
# 'shill wlc to pythonthill wlc to pythonrhill wlc to python2'

# %%
print(str1+str2)
# Out:
# hill wlc to pythonwelcome to Python

# %%
print(str1+ '' +str2)
# Out:
# hill wlc to pythonwelcome to Python

# %%
str1='Hiiii '
str3=' Welcome to python'
str2=input("Enter your name")
print(str1+str2+str3)
# Out:
# Enter your nameSaurabh
# Hiiii Saurabh Welcome to python

# %%
name=input("Enter your name")
'hii'+' '+name+' '+ "Welcome to python"
# Out:
# Enter your nameSaurabh
# 'hii Saurabh Welcome to python'

# %%
a=20
b=40

# %%
a=b

# %%
a
# Out:
# 40

# %%
b
# Out:
# 40
