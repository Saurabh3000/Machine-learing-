# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
dataframe=pd.read_csv("ires.csv.csv")

# %%
dataframe.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
dataframe.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
x=dataframe.iloc[:,2:3]
y=dataframe.iloc[:,3:4]

# %%
plt.scatter(x,y)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#      petal_length
# 79            3.5
# 74            4.3
# 51            4.5
# 93            3.3
# 27            1.5
# ..            ...
# 109           6.1
# 110           5.1
# 23            1.7
# 136           5.6
# 4             1.4
#
# [120 rows x 1 columns]

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predict=model.predict(x_test)

# %%
predict
# Out:
# array([[1.34587134],
#        [0.25687429],
#        [1.68094735],
#        [1.59717835],
#        [1.17833333],
#        [0.3406433 ],
#        [2.43486839],
#        [2.05790787],
#        [2.26733038],
#        [0.21498979],
#        [2.30921488],
#        [1.47152485],
#        [0.17310529],
#        [2.18356138],
#        [1.97413887],
#        [0.25687429],
#        [1.55529385],
#        [1.51340935],
#        [0.25687429],
#        [1.84848536],
#        [1.76471636],
#        [1.26210234],
#        [1.89036986],
#        [1.59717835],
#        [1.55529385],
#        [0.25687429],
#        [0.21498979],
#        [0.25687429],
#        [1.38775584],
#        [1.93225437]])

# %%
y_test
# Out:
#      petal_width
# 67           1.0
# 7            0.2
# 72           1.5
# 50           1.4
# 81           1.0
# 18           0.3
# 117          2.2
# 104          2.2
# 107          1.8
# 33           0.2
# 131          2.0
# 87           1.3
# 40           0.3
# 135          2.3
# 140          2.4
# 15           0.4
# 58           1.3
# 66           1.5
# 10           0.2
# 115          2.3
# 141          2.3
# 69           1.1
# 139          2.1
# 63           1.4
# 54           1.5
# 31           0.4
# 6            0.3
# 48           0.2
# 95           1.2
# 112          2.1

# %%
length=input("Enter length")
length=np.array(length)
length.shape
length=length.reshape(-1,1)
model.predict(length)
# Out:
# Enter length2
# C:\Users\sai\anaconda3\lib\site-packages\sklearn\utils\validation.py:73: FutureWarning: Beginning in version 0.22, arrays of bytes/strings will be converted to decimal numbers if dtype='numeric'. It is recommended that you convert the array to a float dtype before using it in scikit-learn, for example by using your_array = your_array.astype(np.float64).
#   return f(**kwargs)
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-21-7aa74d68c880> in <module>
#       3 length.shape
#       4 length=length.reshape(-1,1)
# ----> 5 model.predict(length)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     234             Returns predicted values.
#     235         """
# --> 236         return self._decision_function(X)
#     237
#     238     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     217
#     218         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
# --> 219         return safe_sparse_dot(X, self.coef_.T,
#     220                                dense_output=True) + self.intercept_
#     221
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~\anaconda3\lib\site-packages\sklearn\utils\extmath.py in safe_sparse_dot(a, b, dense_output)
#     151             ret = np.dot(a, b)
#     152     else:
# --> 153         ret = a @ b
#     154
#     155     if (sparse.issparse(a) and sparse.issparse(b)
#
# UFuncTypeError: ufunc 'matmul' did not contain a loop with signature matching types (dtype('<U32'), dtype('<U32')) -> dtype('<U32')
