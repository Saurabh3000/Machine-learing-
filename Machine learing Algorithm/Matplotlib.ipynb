# %% [markdown]
# # Matplotlib

# %% [markdown]
# Matplotlibis is use for data visualization

# %% [markdown]
# 1) Line Plot

# %%
X=[10,20,30,40]
y=[10,20,30,40]

# %%
x
# Out:
# [10, 20, 30, 40]

# %%
y
# Out:
# [10, 20, 30, 40]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y)
plt.xlabel("x")
plt.title("Name of Graph")
plt.ylabel("Y")
# Out:
# Text(0, 0.5, 'Y')

# %%
plt.scatter(x,y)
plt.xlabel("x")
plt.title("Name of Graph")
plt.ylabel("Y")
# Out:
# Text(0, 0.5, 'Y')

# %%
plt.subplot(2,2,1)
plt.plot(x,y,'r--')
plt.subplot(2,2,2)
plt.plot(x,y,'g*--')
plt.subplot(2,2,3)
plt.scatter(x,y,c='b')
plt.subplot(2,2,4)
plt.scatter(x,y,c='g')

# %%
x=[2,8,10]
y=[11,16,9]

x2=[3,9,11]
y2=[6,15,11]

# %%
plt.subplot(2,1,1)
plt.bar(x,y)
plt.subplot(2,1,2)
plt.bar(x2,y2)
# Out:
# <BarContainer object of 3 artists>
